# %% [markdown]
# ## 2021 금융 데이터 경진대회
#
# ### 1. 대회 기간
#
# - 접수 : ~ 2021.07.12
# - 결과물 제출 : ~2021.09.06(월)
#
# ### 2. 관련 링크 및 안내 내용물
#
# - [대회 신청 링크](https://www.findatacontest2021.com/index.php)
# - [샘플 데이터 링크](https://www.findatamall.or.kr/fsec/dataProd/generalDataProd.do?cmnx=44&sCharge=charge&sFree=free&sNego=nego&searchType=00&sKeyword=2021%EA%B8%88%EC%9C%B5%EB%8D%B0%EC%9D%B4%ED%84%B0%EA%B2%BD%EC%A7%84%EB%8C%80%ED%9A%8C&sTaxonomy=200&sOrderByType=orderByDate)
# - [금융데이터 거래소](https://www.findatamall.or.kr/fsec/main/main.do?cmnx=1)
#
# - [팀 분석 내용](https://github.com/RyanKor/financial-data-competition-2021/issues/2)
#
# ### 3. 선정 주제
#
# - 동학개미운동에 참여한 신규 고객정보를 토대로 경기 변화에 따른 투자 패턴 예측하기
#
#
# #### 3-2 예상 Insight
#
# - 경기 회복 & 불황에 따른 고객들의 투자 심리 변화 예측 및 실거래 패턴 예측
#
# - 경기 변화에 따른 금융사들의 신규 금융 상품 개발 제안
#
# ### 4. 결과물 도출 일정
#
# - 6월 4째주 : 팀 주제 선정 및 금융 데이터 대회 접수 (완료)
# - 7월 1째주 : 환경 설정 및 가공 방향 MD 작성, 사용할 ML 알고리즘 지정 (완료)
# - 7월 2째주 ~ 8월 중순 : 결과물 제작
# - 8월 4째주 ~ 9월 5일 : 결과물 리뷰
# - 9월 6일 : 제출
#
#
# ### 5. 활용 데이터
#
# - 한국투자증권 동학개미운동 신규고객투자정보
#
# - 신한은행 서울시지역단위 ‘소득’, ’지출’, ‘금융자산’ 정보
#
#
# ### 6. 분석 배경
#
# - 제태크의 한 분야인 주식 거래에 관련한 데이터는 사회 초년생인 우리에게 삶에 있어 피와 살이 되는 좋은 정보가 될 것이고
#
# - 코로나 발생을 기점으로 20 ~ 30대의 주식 거래 참여 인원의 증가하면서 기존 주식 거래하는 인원들과 다른 거래 패턴을 가질 것이라 가설을 세움
#
# - 무엇보다 미디어에서 자주 언급되는 빚투 (빚내어 투자) & 영끌 (영혼까지 끌어모아 부동산 투자) 인원이 늘어났다는 것을 자주 볼 수 있는데 신한은행에서 제공하는 서울시 시민 데이터 중 금융 & 부동산 담보 대출 금액과 한국투자증권 동학개미 운동을 엮어 이러한 대출을 통한 투자 비율을 분석할 수 있다는 것을 데이터셋을 통해 확인하게 되었다.(비교 분석하여 대출을 통한 투자 비율을 유추하고자 한다.)
#
# - 최종적으론 가공한 데이터를 토대로 사용자들이 구매하는 주식의 테마 & 카테고리 패턴을 분석할 수 있을 것으로 보이며 19년 대비 20년의 투자 패턴을 미디어 보도 자료와 비교 & 대조하면서 경기 변동에 따른 한국인들의 투자 패턴을 예측할 것으로 보인다.
#
#
# ### 7. 분석 기법
#
# - 과거 데이터를 토대로 미래 데이터 예측을 위해 머신러닝 기법을 사용해 예측 모델을 생성해 동학개미운동 참여자들의 투자 패턴을 파악한다.
#
# - 2020년 동학개미운동 투자자 및 2019년 기존 투자자들의 투자 패턴 비교 및시각화
#
#
# ---
#
# #### 분석해야할 것
#
# --> 분석한 내용을 뉴스 기사와 분석해서 정확한 방향으로 가고 있는지 확인하는 것도 가능하다.
# --> 어떤 정보를 시각화를 통해 그래프로 보여줄 것인가?
#
# - 주식 투자를 처음 해본 (신규 계좌를 오픈한) 사람들의 전체 주식 거래량?
# - 전체 늘어난 주식 계좌 수
# - 주식의 구매 목적이 무엇인가? 장기 투자인가? 단타인가? 한탕주의인가? (1년 데이터 정보가 있으므로 3,6,9개월 단위로 주식 구매 - 판매 패턴 파악 가능)
#     - 유입되는 자금의 성향이 미래 지향적인가? (몇 몇 유튜브들을 통해 유입되는 자금들이 미래 지향적이라는 언급이 보임)
# - 계좌를 오픈한 연령대 분류하기 (미성년자 계좌 오픈 수가 많다고 하는데, 실제로 그런지)
# - 구매 횟수 당 금액 분류하기 (한 번에 몰빵해서 주식을 구매하는지, 분할매수하는지 확인 필요)
# - 대출해서 주식 투자에 어느 정도 비율이 투입되어 있는가? (대출 금액 / 전체 자산 -> 전체 자산 = 대출 + 순자산)
# - 사람들이 알고 있는 종목만 구매하는지 확인하는 방법은? (즉, 우량주 중심으로 투자했는가?)

# %% [markdown]
# ## 프로젝트 시작을 위한 라이브러리 정의
#
# - 동학개미운동 참여자들의 투자 패턴을 파악하기 위해서는 사용자들의 성향 파악을 위한 시각화 툴을 활용하는 것이 필수이다.
#
# - 또한 미래 정보 예측이 결과물에 포함되어야하므로 적절한 머신러닝 알고리즘을 사용하는 것도 중요하다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

print("Library Working")
# Out:
# Library Working

# %% [markdown]
# ## 한국투자증권 동학개미 운동 정보 호출
#
# - [동학개미운동 신규 고객 투자 정보 거래소 페이지](https://www.findatamall.or.kr/fsec/dataProd/generalDataProdDetail.do?cmnx=44&goods_id=65be7bde-aec2-11eb-9f58-f220ef21bb88)
#
# - 데이터 가공 전 제공받는 데이터에 포함되는 필드 및 Feature 확인
#
# - 동학개미운동 신규 고객 투자 정보
#     1. 추출 대상 고객
#         - 동학개미운동(20.01.20~20.03.31) 기간 동안 당사 신규 고객으로 등록하고 국내주식을 매매한 고객 약 27만명 중, 거래내역 횟수가 총 30회 이상인 고객 약 2.5만명(10% 수준) 랜덤추출
#     2.제공 데이터 정보
#         - Column : 24개(고객정보 4개, 매매정보 8개, 종목정보 12개) - Rows : 845,940개
#     3. 데이터 사전 처리 내용(익명처리 강화 목적)
#         - 총체결금액, 총체결수량, 주문수량, 거래수 과다 고객의 거래내역 등 이상치 제거 및 대체값 생성, 범주화, 샘플링 등을 통해 익명처리를 강화 - 종목별 거래 고객의 수가 5명 미만인 경우, 해당 종목 및 거래내역 삭제 진행
#         - 총 거래내역에서 고객구분코드별/주문일자별 거래내역의 50%(홀수인 경우 반올림) 랜덤 추출 진행   (따라서, 최종 데이터 셋에는 고객별 거래내역 건수 30건 미만, 종목별 거래 고객수 5명 미만인 데이터가 존재할 수 있음)
#     4. 참고사항 - 금융보안원에서 요청한 익명처리 강화를 수행하기 위해 사전에 제공되었던 샘플데이터와 다소 차이가 발생하게 되었음
#         - 익명처리 강화로 인해 데이터 간 정합성이 일치하지 않을 수 있으며, 이러한 점을 감안하여 향후 분석 결과를 심사할 예정
#
# ![image.png](attachment:image.png)

# %%
# 사용 데이터 2가지 : 한국투자증권 동학개미운동 신규고객투자정보 & 신한은행 서울시지역단위 ‘소득’, ’지출’, ‘금융자산’ 정보
kor_invest = pd.read_csv('./data/original/han_tu.csv')
kor_invest.head()
# Out:
#     고객구분코드      주문일자  고객성별구분코드  동일나이군구분코드 주소(시도)  주문시간대          상품번호  \
# 0    A0001  20200128         1         30     경기      1  00000A091970
# 1    A0001  20200130         1         30     경기      3  00000A045060
# 2    A0001  20200313         1         30     경기      1  00000A253840
# 3   A00010  20200220         1         20     경남      3  00000A009190
# 4  A000100  20200211         2         40     서울      1  00000A001740
#
#          상품명  거래소구분코드  매도매수구분코드  ...   총체결금액   전일종가   당일시가   일중고가   일중저가  \
# 0       나노캠텍        3         2  ...   75900   3215   3710   4125   3660
# 1         오공        3         2  ...  154200   7690   8150   8380   7360
# 2        수젠텍        3         2  ...  118000  13600  12200  12250  10150
# 3    대양금속보통주        2         2  ...   49070   3615   3615   3675   3475
# 4  SK네트웍스보통주        2         1  ...   14625   4780   4800   4885   4800
#
#     당일종가      거래수량          거래대금  상한가여부  하한가여부
# 0   4095  17266597  6.732331e+10      N      N
# 1   7920  15686931  1.250000e+11      N      N
# 2  10750   3731106  4.078277e+10      N      N
# 3   3505    635410  2.250893e+09      N      N
# 4   4850   1263089  6.112027e+09      N      N
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 신한은행 서울시 지역단위 ‘소득’, ’지출’, ‘금융자산’ 정보 호출
#
# - 서울시에 거주하는 신한은행 거래 고객의 지역(집계구), 직장인여부, 성별, 연령구분에 따른 평균 금융 정보 제공
#     - 대상 기간 : 2019년 ~ 2021년 3월, 9월 월별 데이터
#     - 금융 정보 : 소득, 지출, 금융자산, 부채
#         - ex) '2020년 3월', '가양동 A 지역 거주', '30대', '직장인', '남성' 들의 금융 정보 평균 * 집계구 : 행정경계(읍/면/동)의 1/30 규모로, 통계청에서 통계정보를 제공하는 최소 통계구역 단위 경계

# %% [markdown]
# ### 2019년 3월 데이터

# %%
shinhan_bank = pd.read_csv('./data/original/finance_data201903.csv')
shinhan_bank.head()
# Out:
#      기준년월  지역구     법정동코드  법정동         집계구코드  나이  성별  직장인여부  급여입금  가맹점매출입금  \
# 0  201903  강남구  11680101  역삼동  1.123060e+12   2   1      0     0        0
# 1  201903  강남구  11680101  역삼동  1.123060e+12   2   2      0     0        0
# 2  201903  강남구  11680101  역삼동  1.123060e+12   3   1      0     0        0
# 3  201903  강남구  11680101  역삼동  1.123060e+12   3   2      0     0        0
# 4  201903  강남구  11680101  역삼동  1.123060e+12   4   1      0     0        0
#
#    연금입금    총소비금액    총수신금액    예적금금액  신탁금액  수익증권금액  신용대출금액  담보대출금액  주택대출금액  \
# 0     0  2018319  2430312        0     0       0       0       0       0
# 1     0  2326837  2221251        0     0       0       0       0       0
# 2     0  1771639  1382057  1841250     0       0       0       0       0
# 3     0  1745601  2902578  3561440     0       0       0       0       0
# 4     0  1712433  1746992  8831666     0       0       0       0       0
#
#    전세자금대출금액
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %% [markdown]
# ### 2019년 9월 데이터

# %%
shinhan_bank = pd.read_csv('./data/original/finance_data201909.csv')
shinhan_bank.head()
# Out:
#      기준년월  지역구     법정동코드  법정동         집계구코드  나이  성별  직장인여부     급여입금  가맹점매출입금  \
# 0  201909  강남구  11680101  역삼동  1.123060e+12   2   1      0        0        0
# 1  201909  강남구  11680101  역삼동  1.123060e+12   2   2      0        0        0
# 2  201909  강남구  11680101  역삼동  1.123060e+12   3   1      0        0        0
# 3  201909  강남구  11680101  역삼동  1.123060e+12   3   1      1  3390549        0
# 4  201909  강남구  11680101  역삼동  1.123060e+12   3   2      0        0        0
#
#    연금입금    총소비금액    총수신금액    예적금금액  신탁금액  수익증권금액  신용대출금액  담보대출금액  주택대출금액  \
# 0     0        0  2225079        0     0       0       0       0       0
# 1     0  2005339  1678077  2447142     0       0       0       0       0
# 2     0  2180768  1041292  2300000     0       0       0       0       0
# 3     0  2734299  8567215        0     0       0       0       0       0
# 4     0  2018705  2256434  3403013     0       0       0       0       0
#
#    전세자금대출금액
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %% [markdown]
# ### 2020년 3월 데이터

# %%
shinhan_bank = pd.read_csv('./data/original/finance_data202003.csv')
shinhan_bank.head()
# Out:
#      기준년월  지역구     법정동코드  법정동         집계구코드  나이  성별  직장인여부     급여입금  가맹점매출입금  \
# 0  202003  강남구  11680101  역삼동  1.123060e+12   2   1      0        0        0
# 1  202003  강남구  11680101  역삼동  1.123060e+12   2   2      0        0        0
# 2  202003  강남구  11680101  역삼동  1.123060e+12   3   1      0        0        0
# 3  202003  강남구  11680101  역삼동  1.123060e+12   3   1      1  3637267        0
# 4  202003  강남구  11680101  역삼동  1.123060e+12   3   2      0        0        0
#
#    연금입금    총소비금액    총수신금액    예적금금액  신탁금액  수익증권금액  신용대출금액  담보대출금액  주택대출금액  \
# 0     0  1252221  3883375        0     0       0       0       0       0
# 1     0   788141   606383        0     0       0       0       0       0
# 2     0  1982886  1551318  4956857     0       0       0       0       0
# 3     0  1706241  7944159  7401428     0       0       0       0       0
# 4     0  1556347  3636467  7956413     0       0       0       0       0
#
#    전세자금대출금액
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %% [markdown]
# ### 2020년 9월 데이터

# %%
shinhan_bank = pd.read_csv('./data/original/finance_data202009.csv')
shinhan_bank.head()
# Out:
#      기준년월  지역구     법정동코드  법정동         집계구코드  나이  성별  직장인여부     급여입금  가맹점매출입금  \
# 0  202009  강남구  11680101  역삼동  1.123060e+12   2   1      0        0        0
# 1  202009  강남구  11680101  역삼동  1.123060e+12   2   2      0        0        0
# 2  202009  강남구  11680101  역삼동  1.123060e+12   3   1      0        0        0
# 3  202009  강남구  11680101  역삼동  1.123060e+12   3   1      1  4213260        0
# 4  202009  강남구  11680101  역삼동  1.123060e+12   3   2      0        0        0
#
#    연금입금    총소비금액     총수신금액    예적금금액  신탁금액  수익증권금액    신용대출금액  담보대출금액  주택대출금액  \
# 0     0  1506228   3953913        0     0       0         0       0       0
# 1     0   533411    229001        0     0       0         0       0       0
# 2     0  1152635   1351522  3816857     0       0         0       0       0
# 3     0  2563174  10205646  5644285     0       0  65355500       0       0
# 4     0  1523024   3345200  6600528     0       0         0       0       0
#
#    전세자금대출금액
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %% [markdown]
# ### 2021년 03월 데이터

# %%
shinhan_bank = pd.read_csv('./data/original/finance_data202103.csv')
shinhan_bank.head()
# Out:
#      기준년월  지역구     법정동코드  법정동         집계구코드  나이  성별  직장인여부     급여입금  가맹점매출입금  \
# 0  202103  강남구  11680101  역삼동  1.123060e+12   2   1      0        0        0
# 1  202103  강남구  11680101  역삼동  1.123060e+12   2   2      0        0        0
# 2  202103  강남구  11680101  역삼동  1.123060e+12   3   1      0        0        0
# 3  202103  강남구  11680101  역삼동  1.123060e+12   3   1      1  3342604        0
# 4  202103  강남구  11680101  역삼동  1.123060e+12   3   2      0        0        0
#
#    연금입금    총소비금액     총수신금액    예적금금액  신탁금액  수익증권금액  신용대출금액     담보대출금액  주택대출금액  \
# 0     0  2281097   5125045        0     0       0       0          0       0
# 1     0  1365430   1145088        0     0       0       0          0       0
# 2     0  1887395   1645858  2890000     0       0       0          0       0
# 3     0  2033384  10880050  6925250     0       0       0          0       0
# 4     0  1366078   2805100  5898600     0       0       0  152762581       0
#
#    전세자금대출금액
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
