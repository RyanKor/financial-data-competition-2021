# %% [markdown]
# # [2021금융데이터경진대회] 신설법인데이터 (Sample)
#
# - [신설법인데이터 거래소 페이지](https://www.findatamall.or.kr/fsec/dataProd/generalDataProdDetail.do?cmnx=44&goods_id=fdbd89e3-b13a-11eb-9f58-f220ef21bb88)
#
# - 데이터 가공 전 제공받는 데이터에 포함되는 필드 및 Feature 확인
#
# |필드명|	필드형식	| 필드설명|
# | --- | ---- |---- |
# |KEDCD|	텍스트|	KEDCD|
# |기업명2|	텍스트|	기업명|
# |업종구분1|	텍스트|	업종코드|
# |업종구분|	텍스트|	업종코드_10차|
# |일자(설립)|	날짜|	설립일자|
# |연령	|텍스트	|연령구간|
# |성별	|텍스트	|성별구분|
# |우편번호|	텍스트|	우편번호|
# |광역시도|	텍스트|	시도|
# |시군구|	텍스트|	구군|
# |법정동|	텍스트|	법정동|
# |위도	|위치	|위도|
# |경도|	위치	|경도|
# |기업명1|	텍스트|	기업상태|
# |기업명	|텍스트	|기업형태|
# |주식수|	숫자|	주식수|
# |주당금액	|숫자|	주당금액|
# |자본금	|숫자|	자본금|
# |행정동	|텍스트|	행정동|

# %%
import pandas as pd

new_company = pd.read_excel('../data/new_company.xlsx')
new_company.head()
# Out:
#      KEDCD     기업명    업종코드 업종코드_10차      설립일자  연령구간 성별구분   우편번호  시도       구군  \
# 0  2651374      옥*  L68121   L68121  20191203    60   여성  61264  광주       북구
# 1  2673958    청신산*  C17110   C17110  20191224    71   남성  28157  충북  청주시 흥덕구
# 2  8276879  솔라미엄환*  D35119   D35114  20191202    69   여성  57785  전남      광양시
# 3  8276884      예*  F42492   F42492  20191202    84   남성  58325  전남      나주시
# 4  8276885     망고*  C10309   C10309  20191202    72   남성  58275  전남      나주시
#
#     법정동          위도         경도     기업상태  기업형태    주식수   주당금액        자본금   행정동
# 0   운암동  126.873604  35.171875  살아있는 등기  주식회사   5000  10000   50000000  운암1동
# 1   오송읍  127.343513  36.644960  살아있는 등기  주식회사   1000   5000    5000000   오송읍
# 2    중동  127.697751  34.943724  살아있는 등기  주식회사  20000   5000  100000000   중마동
# 3  빛가람동  126.793223  35.019839  살아있는 등기  주식회사  21000  10000  210000000  빛가람동
# 4   동수동  126.689430  34.985337  살아있는 등기  주식회사  10000  10000  100000000   이창동
