# %% [markdown]
# # [2021금융데이터경진대회] 서울시 지역단위 '소득', '지출', '금융자산' 정보 (Sample)
#
# - [서울시 지역단위 '소득', '지출', '금융자산' 정보](https://www.findatamall.or.kr/fsec/dataProd/generalDataProdDetail.do?cmnx=44&goods_id=6e7665e9-af0e-11eb-9f58-f220ef21bb88)
# - 데이터 가공 전 제공받는 데이터에 포함되는 필드 및 Feature 확인
#
# |필드명|	필드형식	| 필드설명|
# | --- | ---- |---- |
# |기준년월	|텍스트	|기준년월|
# |도로명	|텍스트|	법정동| 이름|
# |법정동코드	|텍스트	|법정동| 코드|
# |집계구코드	|텍스트	|집계구 |코드|
# |직장인여부	|텍스트	|직장인여부 (여 : 1 , 부 :0)|
# |성별	|텍스트	|성별 (남 : 1, 여 :0)|
# |연령	|텍스트	|20대, 30대, 40대, 50대, 60대|
# |급여	|텍스트	|직장인 급여 입금 금액|
# |매출건수	|텍스트	|자영업자 카드 가맹점 매출대금 입금 금액|
# |연금	|텍스트	|연금소득자 연금 입금 금액|
# |총지출	|텍스트	|총지출금액|
# |총수신	|텍스트	|금융자산 합계|
# |예금, 적금	|텍스트	|예금, 적금 잔액|
# |신탁	|텍스트	|신탁 상품 잔액|
# |수익증권	|텍스트	|수익증권(펀드 등) 상품 잔액|
# |신용대출건수	|텍스트	|신용대출 잔액|
# |담보대출잔액	|텍스트	|담보대출 잔액|
# |주택대출	|텍스트	|주택담보대출 잔액|
# |전세대출	|텍스트	|전세자금대출 잔액|

# %%
import pandas as pd

shinhan_bank = pd.read_excel('../data/shinhanbank.xlsx')
shinhan_bank.head()
# Out:
#      기준년월 법정동 이름      법정동 코드          집계구 코드  직장인여부  성별  연령구분            급여  \
# 0  201903    가양동  1150010400  1150010400-101      0   1    20  0.000000e+00
# 1  201903    가양동  1150010400  1150010400-101      1   1    20  2.208987e+06
# 2  201903    가양동  1150010400  1150010400-101      0   1    30  0.000000e+00
# 3  201903    가양동  1150010400  1150010400-101      1   1    30  3.155985e+06
# 4  201903    가양동  1150010400  1150010400-101      0   1    40  0.000000e+00
#
#            가맹점매출            연금           총지출           총수신        예금, 적금  \
# 0   15040.026773    197.185239  7.173819e+05  2.928034e+06  1.616215e+06
# 1       0.000000  34191.062305  2.273580e+06  7.629768e+06  3.545905e+06
# 2   88991.188587   5622.178804  1.057316e+06  6.258182e+06  2.495409e+06
# 3   14625.447296  61748.330889  2.859349e+06  1.554034e+07  6.122613e+06
# 4  179426.750744   6628.330357  1.250963e+06  8.405713e+06  3.581589e+06
#
# ...
